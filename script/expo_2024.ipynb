# %%
import pandas as pd

dados = pd.read_csv('EXP_2024_MUN.csv', sep=';', encoding='utf-8')
dados.head(500)
# Out:
#      CO_ANO  CO_MES   SH4  CO_PAIS SG_UF_MUN   CO_MUN  KG_LIQUIDO   VL_FOB
# 0      2024       2  8708      158        MG  3106705        3346    97359
# 1      2024       9  1516      845        SP  3425904      349090   541361
# 2      2024       7  8536      158        SC  4208906        1711    20706
# 3      2024       8  4010       63        SP  3452205        4586   176026
# 4      2024      12   701      476        SC  4216206         330      274
# ..      ...     ...   ...      ...       ...      ...         ...      ...
# 495    2024       5  1604      580        ES  3205309          64      483
# 496    2024       4  6910      158        MG  3157807       11708    13163
# 497    2024       3   805      244        RJ  3304557          88      778
# 498    2024      12  2710      831        AM  1302603      132913   168383
# 499    2024       3  7304      275        MG  3106200      473370  1112221
#
# [500 rows x 8 columns]

# %%
print("--- ESTRUTURA DAS COLUNAS (SCHEMA) ---")
print(dados.info())
# Out:
# --- ESTRUTURA DAS COLUNAS (SCHEMA) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144828 entries, 0 to 1144827
# Data columns (total 8 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   CO_ANO      1144828 non-null  int64
#  1   CO_MES      1144828 non-null  int64
#  2   SH4         1144828 non-null  int64
#  3   CO_PAIS     1144828 non-null  int64
#  4   SG_UF_MUN   1144828 non-null  object
#  5   CO_MUN      1144828 non-null  int64
#  6   KG_LIQUIDO  1144828 non-null  int64
#  7   VL_FOB      1144828 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 69.9+ MB
# None

# %%
dados['VL_FOB']
# Out:
# 0           97359
# 1          541361
# 2           20706
# 3          176026
# 4             274
#             ...
# 1144823        79
# 1144824      1200
# 1144825      5454
# 1144826      2390
# 1144827        72
# Name: VL_FOB, Length: 1144828, dtype: int64
